# %% [markdown]
# <a href="https://colab.research.google.com/github/Krupakar-Reddy-S/SST-Trimester3-Codebase/blob/main/Probability_and_Statistics/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("movies.csv")

# %%
data
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
pd.Series([1, 4, 6, 2])
# Out:
# 0    1
# 1    4
# 2    6
# 3    2
# dtype: int64

# %%
nums = np.random.randint(1, 10, size=(5, 4))
nums
# Out:
# array([[9, 7, 8, 5],
#        [1, 1, 9, 5],
#        [1, 9, 4, 2],
#        [9, 8, 6, 2],
#        [2, 8, 7, 3]])

# %%
df = pd.DataFrame(nums)
df
# Out:
#    0  1  2  3
# 0  9  7  8  5
# 1  1  1  9  5
# 2  1  9  4  2
# 3  9  8  6  2
# 4  2  8  7  3

# %%
# Our dataset has information on 1465 movies with 12 properties
data.shape
# Out:
# (1465, 12)

# %%
# head gives the first n rows
data.head(10) # n=5 (default)
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
# 5           9  43606  250000000         155   873260194
# 6          10  43607  270000000          57   391081192
# 7          11  43608  200000000         107   586090727
# 8          12  43609  200000000         145  1065659812
# 9          13  43610  255000000          49    89289910
#
#                                         title  vote_average  vote_count  \
# 0                                      Avatar           7.2       11800
# 1    Pirates of the Caribbean: At World's End           6.9        4500
# 2                                     Spectre           6.3        4466
# ...

# %%
# tail gives the last n rows
data.tail(2)
# Out:
#       Unnamed: 0     id  budget  popularity  revenue        title  \
# 1463        4749  48376       0           3        0      Slacker
# 1464        4768  48395  220000          14  2040920  El Mariachi
#
#       vote_average  vote_count  director_id  year month     day
# 1463           6.4          77         5535  1990   Jul  Friday
# 1464           6.6         238         5097  1992   Sep  Friday

# %%
# displays the information of the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1465 non-null   int64
#  1   id            1465 non-null   int64
#  2   budget        1465 non-null   int64
#  3   popularity    1465 non-null   int64
#  4   revenue       1465 non-null   int64
#  5   title         1465 non-null   object
#  6   vote_average  1465 non-null   float64
#  7   vote_count    1465 non-null   int64
#  8   director_id   1465 non-null   int64
#  9   year          1465 non-null   int64
#  10  month         1465 non-null   object
#  11  day           1465 non-null   object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 137.5+ KB

# %%
data.describe()
# Out:
#         Unnamed: 0            id        budget   popularity       revenue  \
# count  1465.000000   1465.000000  1.465000e+03  1465.000000  1.465000e+03
# mean   1627.391809  45225.191126  4.802295e+07    30.855973  1.432539e+08
# std    1187.182894   1189.096396  4.935541e+07    34.845214  2.064918e+08
# min       0.000000  43597.000000  0.000000e+00     0.000000  0.000000e+00
# 25%     639.000000  44236.000000  1.400000e+07    11.000000  1.738013e+07
# 50%    1425.000000  45022.000000  3.300000e+07    23.000000  7.578164e+07
# 75%    2393.000000  45990.000000  6.600000e+07    41.000000  1.792469e+08
# max    4768.000000  48395.000000  3.800000e+08   724.000000  2.787965e+09
#
#        vote_average    vote_count  director_id         year
# count   1465.000000   1465.000000  1465.000000  1465.000000
# mean       6.368191   1146.396587  5040.192491  2002.615017
# std        0.818033   1578.077438   258.059631     8.680141
# min        3.000000      1.000000  4762.000000  1976.000000
# ...

# %%
data['vote_average'] # this is a Series (one column)
# Out:
# 0       7.2
# 1       6.9
# 2       6.3
# 3       7.6
# 4       5.9
#        ...
# 1460    7.9
# 1461    7.4
# 1462    6.0
# 1463    6.4
# 1464    6.6
# Name: vote_average, Length: 1465, dtype: float64

# %%
data[['revenue', 'budget']] # multiple Series together make a DataFrame
# Out:
#          revenue     budget
# 0     2787965087  237000000
# 1      961000000  300000000
# 2      880674609  245000000
# 3     1084939099  250000000
# 4      890871626  258000000
# ...          ...        ...
# 1460      321952          0
# 1461     3151130      27000
# 1462           0          0
# 1463           0          0
# 1464     2040920     220000
#
# [1465 rows x 2 columns]

# %%
data['revenue'].min(), data['revenue'].max()
# Out:
# (0, 2787965087)

# %%
data['budget'].min(), data['budget'].max()
# Out:
# (0, 380000000)

# %%
vote_mask7 = data['vote_average'] > 7
vote_mask7
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1460     True
# 1461     True
# 1462    False
# 1463    False
# 1464    False
# Name: vote_average, Length: 1465, dtype: bool

# %%
data[vote_mask7]
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 3              3  43600  250000000         112  1084939099
# 14            19  43616  250000000         120   956019788
# 16            22  43619  250000000          94   958400000
# 19            25  43622  200000000         100  1845034188
# ...          ...    ...        ...         ...         ...
# 1456        4694  48321      10000          20     7000000
# 1457        4696  48323          0           5           0
# 1458        4708  48335      60000          27     3221152
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# ...

# %%
data[ data['vote_average'] < 4 ]
# Out:
#       Unnamed: 0     id    budget  popularity   revenue  \
# 164          272  43869  90000000           1  10372291
# 351          601  44198         0           9         0
# 549         1001  44598  50000000           8  12764201
# 812         1606  45203  30000000          10  84646831
# 896         1806  45403  26000000           5         0
# 944         1939  45536  25000000           7   2405420
# 1010        2113  45710  20000000          10  48548426
# 1012        2122  45719  20000000           6  86865564
# 1036        2194  45791  25000000          16  14109284
# 1058        2237  45834  20000000           9  10442808
# 1383        3853  47453   3500000           4         0
#
#                                       title  vote_average  vote_count  \
# 164                          Town & Country           3.7          16
# 351                              Rollerball           3.4         106
# 549   Street Fighter: The Legend of Chun-Li           3.9         112
# ...

# %%
data[ (data['year'] == 2015) & (data['vote_average'] > 7) ]
# Out:
#      Unnamed: 0     id     budget  popularity     revenue  \
# 30           44  43641  190000000         102  1506249360
# 78          127  43724  150000000         434   378858340
# 106         176  43773  135000000         100   532950503
# 162         270  43867  108000000         167   630161890
# 312         531  44128   75000000          48   108145109
# 394         684  44281   44000000          68   155760117
# 625        1173  44770   35000000          53   194564672
# 635        1187  44784   40000000          48   165478348
# 808        1597  45194   30000000          65    91709827
# 833        1696  45293   28000000          61   201634991
# 839        1704  45301   28000000          57   133346506
#
#                        title  vote_average  vote_count  director_id  year  \
# 30                 Furious 7           7.3        4176         4794  2015
# 78        Mad Max: Fury Road           7.2        9427         4845  2015
# ...

# %%
# top 5 highest rated movies
data_vote_sorted = data.sort_values(by=['vote_average'], ascending=[False])

# %%
# after year 2000
data_vote_sorted[ data_vote_sorted['year'] > 2000 ]
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 45            65  43662  185000000         187  1004558444
# 199          329  43926   94000000         123  1118888979
# 59            96  43693  160000000         167   825532764
# 58            95  43692  165000000         724   675120017
# 776         1532  45129   30000000          74   174600318
# ...          ...    ...        ...         ...         ...
# 351          601  44198          0           9           0
# 1383        3853  47453    3500000           4           0
# 1012        2122  45719   20000000           6    86865564
# 1058        2237  45834   20000000           9    10442808
# 1036        2194  45791   25000000          16    14109284
#
#                                               title  vote_average  vote_count  \
# 45                                  The Dark Knight           8.2       12002
# 199   The Lord of the Rings: The Return of the King           8.1        8064
# ...

# %%
data.sort_values(by=['year', 'vote_average'], ascending=[False, False])
# Out:
#       Unnamed: 0     id     budget  popularity    revenue  \
# 1344        3584  47181    5000000          22   24804129
# 519          941  44538   50000000          42   69411370
# 617         1160  44757   40000000          68  320170008
# 54            78  43675  175000000          94  966550600
# 225          370  43967   90000000          51  334901337
# ...          ...    ...        ...         ...        ...
# 1435        4482  48095     600000          10          0
# 1176        2693  46290          0           3          0
# 1427        4325  47934    1300000          58   28262574
# 1379        3809  47409    3800000          17   23689877
# 912         1838  45435    2800000          25   60922980
#
#                                           title  vote_average  vote_count  \
# 1344                                       Race           7.1         478
# 519   13 Hours: The Secret Soldiers of Benghazi           7.0         938
# ...
